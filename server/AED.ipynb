# %%
import pandas as pd

# Read the data
data = pd.read_excel('./data/mensal_estados-desde_jan2013.xlsx', skiprows=16)

# Show the data
data.head()
# Out:
#          MÊS           PRODUTO    REGIÃO    ESTADO
# 0 2013-01-01  ETANOL HIDRATADO     NORTE      ACRE  \
# 1 2013-01-01  ETANOL HIDRATADO  NORDESTE   ALAGOAS
# 2 2013-01-01  ETANOL HIDRATADO     NORTE     AMAPA
# 3 2013-01-01  ETANOL HIDRATADO     NORTE  AMAZONAS
# 4 2013-01-01  ETANOL HIDRATADO  NORDESTE     BAHIA
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA
# 0                           166              R$/l                2.552  \
# 1                           460              R$/l                2.303
# 2                            38              R$/l                2.258
# 3                           376              R$/l                2.319
# 4                          2029              R$/l                2.187
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# 0                  0.132                  2.35                  3.12  \
# 1                  0.071                  2.15                  2.60
# ...
